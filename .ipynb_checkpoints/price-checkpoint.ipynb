# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Datasets

# %%
price = pd.read_csv('prices.csv')

# %%
price.head()
price.shape
# Out:
# (851264, 7)

# %% [markdown]
# #### 1. Selecting and plotting GE, GOOG, MSFT, TSLA respectively by using seaborn pairplot.

# %% [markdown]
# #### GE

# %%
ge = price[price['symbol'] == 'GE']
ge
# Out:
#               date symbol       open      close        low       high  \
# 434     2010-01-04     GE  15.220000  15.450000  15.150000  15.640000
# 902     2010-01-05     GE  15.460000  15.530000  15.450000  15.670000
# 1370    2010-01-06     GE  15.530000  15.450000  15.440000  15.620000
# 1838    2010-01-07     GE  15.480000  16.250000  15.430000  16.480000
# 2306    2010-01-08     GE  16.309999  16.600000  16.270000  16.690001
# ...            ...    ...        ...        ...        ...        ...
# 848957  2016-12-23     GE  31.870001  31.879999  31.770000  31.940001
# 849457  2016-12-27     GE  31.889999  31.900000  31.850000  32.049999
# 849957  2016-12-28     GE  31.840000  31.700001  31.670000  31.969999
# 850457  2016-12-29     GE  31.740000  31.709999  31.700001  31.879999
# 850957  2016-12-30     GE  31.629999  31.600000  31.510000  31.799999
#
#              volume
# 434      67079900.0
# 902      64550600.0
# 1370     55464900.0
# 1838    185472300.0
# ...

# %%
ge.describe()
# Out:
#               open        close          low         high        volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean     23.146362    23.151731    22.961163    23.332066  4.855166e+07
# std       4.872662     4.884632     4.882610     4.884163  3.067293e+07
# min      13.990000    13.880000    13.750000    14.260000  1.316150e+07
# 25%      19.002500    19.020000    18.862501    19.165000  3.075432e+07
# 50%      23.595000    23.605001    23.445001    23.760000  4.044950e+07
# 75%      26.765000    26.770000    26.600000    26.935001  5.727508e+07
# max      32.959999    32.930000    32.740002    33.000000  4.313326e+08

# %%
ge.set_index('date', inplace = True)

# %%
ge[['open','close']].plot(figsize = (15,5))

# %%
sns.pairplot(ge[['open','close']])
plt.title('GE stock exchange data')
plt.show()

# %% [markdown]
# #### GOOG

# %%
goog = price[price['symbol'] == 'GOOG']

# %%
goog.describe()
# Out:
#               open        close          low         high        volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean    667.988556   667.732200   662.013391   673.341401  4.051179e+06
# std     159.812252   159.790218   159.052972   160.469786  2.933261e+06
# min     438.310758   436.070761   433.630737   442.280760  7.900000e+03
# 25%     548.639605   547.364993   542.753834   553.582514  1.901175e+06
# 50%     613.846067   614.161057   609.356057   619.111038  3.642400e+06
# 75%     749.962820   749.452515   742.882817   756.218456  5.165425e+06
# max    1226.802152  1220.172036  1218.602083  1228.882066  2.976060e+07

# %%
goog[['open','close']].plot(figsize = (15,5))

# %%
sns.pairplot(goog[['open','close']])
plt.title('GOOG stock exchange price')
plt.show()

# %% [markdown]
# ### MSFT

# %%
msft = price[price['symbol'] == 'MSFT']

# %%
msft.describe()
# Out:
#               open        close          low         high        volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean     37.110789    37.129841    36.788621    37.436754  4.579784e+07
# std      10.796157    10.810695    10.725634    10.879890  2.428640e+07
# min      23.090000    23.010000    22.730000    23.320000  8.409600e+06
# 25%      27.799999    27.840000    27.530001    28.002500  2.964580e+07
# 50%      32.930000    33.024999    32.670001    33.340000  4.086645e+07
# 75%      46.027499    46.107500    45.697501    46.527499  5.504572e+07
# max      63.840000    63.619999    63.410000    64.099998  3.193179e+08

# %%
msft[['open','close']].plot(figsize = (20,5))

# %%
sns.pairplot(msft[['open','close']])
plt.title('Stock Exchange Data of MSFT')
plt.show()

# %% [markdown]
# ### TSLA

# %%
tsla = price[price['symbol'] == 'TSLA']
tsla.head()
#### There is no data in tsla
# Out:
# Empty DataFrame
# Columns: [date, symbol, open, close, low, high, volume]
# Index: []

# %%
tsla.shape
# Out:
# (0, 7)

# %% [markdown]
# ### Concating GE GOOG MSFT TSLA

# %%
concat = pd.concat([ge,goog,msft,tsla])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
concat
# Out:
#                 close        date       high        low       open symbol  \
# 2010-01-04  15.450000         NaN  15.640000  15.150000  15.220000     GE
# 2010-01-05  15.530000         NaN  15.670000  15.450000  15.460000     GE
# 2010-01-06  15.450000         NaN  15.620000  15.440000  15.530000     GE
# 2010-01-07  16.250000         NaN  16.480000  15.430000  15.480000     GE
# 2010-01-08  16.600000         NaN  16.690001  16.270000  16.309999     GE
# ...               ...         ...        ...        ...        ...    ...
# 849076      63.240002  2016-12-23  63.540001  62.799999  63.450001   MSFT
# 849576      63.279999  2016-12-27  64.070000  63.209999  63.209999   MSFT
# 850076      62.990002  2016-12-28  63.400002  62.830002  63.400002   MSFT
# 850576      62.900002  2016-12-29  63.200001  62.730000  62.860001   MSFT
# 851076      62.139999  2016-12-30  62.990002  62.029999  62.959999   MSFT
#
#                  volume
# 2010-01-04   67079900.0
# 2010-01-05   64550600.0
# ...

# %%
concat[['open','close']].plot(figsize = (15,5))

# %%
sns.pairplot(concat[['open','close']])
plt.title('Stock Exchange data of whole GE,GOOG,MSFA,TSLA')
plt.show()

# %% [markdown]
# ### Plotting of Stock Performance between jan 2015 to jan 2016

# %%
price.set_index('date', inplace = True)
price
# Out:
#                     symbol        open       close         low        high  \
# date
# 2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
# ...                    ...         ...         ...         ...         ...
# 2016-12-30             ZBH  103.309998  103.199997  102.849998  103.930000
# 2016-12-30            ZION   43.070000   43.040001   42.689999   43.310001
# 2016-12-30             ZTS   53.639999   53.529999   53.270000   53.740002
# 2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000   45.590000
# 2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999   54.480000
#
#                         volume
# date
# ...

# %%
lower_date = "2015-01-01"
upper_date = "2016-01-30"
date_filter = (price.index >lower_date) & (price.index <upper_date)
final_data = price.loc[date_filter]

# %%
final_data.plot(figsize = (15,5))
plt.title('Plotting of Stock Performance between jan 2015 to jan 2016')
plt.show()

# %%
final_data
# Out:
#                     symbol        open       close         low        high  \
# date
# 2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
# ...                    ...         ...         ...         ...         ...
# 2016-01-29             YUM   70.710000   72.370000   70.480000   72.410003
# 2016-01-29             ZBH   98.279999   99.260002   97.320000   99.419998
# 2016-01-29            ZION   22.230000   22.680000   22.090000   22.700001
# 2016-01-29             ZTS   43.200001   43.049999   42.610001   43.360001
# 2016-01-29 00:00:00    AIV   38.520000   39.150002   38.250000   39.230000
#
#                         volume
# date
# ...

# %%
sns.pairplot(final_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-37f18936e9f8> in <module>
#       1 sns.pairplot(final_data)
# ----> 2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# ...

# %%
final_data.columns
# Out:
# Index(['symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %% [markdown]
# ### Calculating the  20 days, 50 days, and  90 days moving average of the above stocks

# %%
twenty = price.rolling(window=20).mean()
twenty.head(20)
# Out:
#                          open    close       low      high     volume
# date
# 2016-01-05 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-06 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-07 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-08 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-11 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-12 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-13 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-14 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-15 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-19 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-20 00:00:00       NaN      NaN       NaN       NaN        NaN
# 2016-01-21 00:00:00       NaN      NaN       NaN       NaN        NaN
# ...

# %%
fifty = price.rolling(window=50).mean()
fifty.tail(50)
# Out:
#                         open    close      low       high     volume
# date
# 2016-12-30           86.0652  85.5858  85.1208  86.384399  2105816.0
# 2016-12-30           85.0682  84.5792  84.1246  85.366800  2107306.0
# 2016-12-30           84.5630  84.0916  83.6412  84.874799  2153850.0
# 2016-12-30           85.1818  84.7054  84.2552  85.493399  2105220.0
# 2016-12-30           83.6566  83.1240  82.7260  83.925199  2107996.0
# 2016-12-30           82.3494  81.8102  81.4056  82.618200  2127472.0
# 2016-12-30           81.9346  81.4102  81.0148  82.204600  2217606.0
# 2016-12-30           83.1576  82.6188  82.2218  83.429400  2191892.0
# 2016-12-30           81.1940  80.6258  80.2684  81.424200  2280374.0
# 2016-12-30           80.8390  80.2706  79.9132  81.062000  2271732.0
# 2016-12-30           81.7276  81.1566  80.7982  81.955000  2219056.0
# 2016-12-30           80.8930  80.3178  79.9626  81.112800  2255834.0
# ...

# %%
ninety = price.rolling(window = 90).mean()
ninety.tail(90)
# Out:
#                           open      close        low       high        volume
# date
# 2016-12-30           97.309333  96.571112  96.075111  97.646433  2.861998e+06
# 2016-12-30           97.418555  96.681334  96.184111  97.761988  2.863716e+06
# 2016-12-30           97.204555  96.472223  95.975778  97.545544  2.858336e+06
# 2016-12-30           97.421000  96.703112  96.202555  97.755655  2.762040e+06
# 2016-12-30           96.881555  96.191112  95.689889  97.218433  2.727072e+06
# ...                        ...        ...        ...        ...           ...
# 2016-12-30           76.994778  76.512111  76.137889  77.286888  2.557988e+06
# 2016-12-30           76.670667  76.197333  75.826111  76.964888  2.571990e+06
# 2016-12-30           76.717333  76.245555  75.873222  77.011444  2.552178e+06
# 2016-12-30 00:00:00  75.252000  74.776444  74.415444  75.531333  2.542131e+06
# 2016-12-30 00:00:00  74.649667  74.177444  73.817444  74.927888  2.539008e+06
#
# [90 rows x 5 columns]
